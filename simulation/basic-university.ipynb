# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd

from SemesterModel import *

# %%
# gpa = []

gpas = pd.DataFrame()

for n in np.arange(100):
    model = SemesterModel(50)
    for s in np.arange(0, 90, 1):

#         for a in model.schedule.agents:
#             gpa.append(a.grade)

        model.step()
     
    model_data = model.datacollector.get_model_vars_dataframe().reset_index()
    gpas = pd.concat([gpas, model_data])

# %%
# np.max(gpa)

# %%
# model.datacollector.get_model_vars_dataframe()

# %%
gpas.groupby('index').mean().plot()
# Out:
# <AxesSubplot:xlabel='index'>

# %%
gpas.plot.scatter(x='index', y='semester_gpa')
# Out:
# <AxesSubplot:xlabel='index', ylabel='semester_gpa'>

# %%
gpas.semester_gpa.hist(log=True, bins=np.arange(0, 90, 1))
# Out:
# <AxesSubplot:>
